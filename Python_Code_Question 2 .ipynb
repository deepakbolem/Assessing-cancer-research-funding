# %% [markdown]
# # Business Question 2

# %%
import numpy as np
import pandas as pd

# %%
Dataset1 = pd.read_csv("/Users/ashadeepikapenagganti/Documents/Datasets/Dataset 1 - USCS_RaceEthnicity.csv")

# %%
Dataset1
# Out:
#                         CancerType  Year                       Race  \
# 0      Other Female Genital Organs  2019  All Races and Ethnicities
# 1                      Nasopharynx  2019  All Races and Ethnicities
# 2                           Larynx  2019  All Races and Ethnicities
# 3             Non-Hodgkin Lymphoma  2019  All Races and Ethnicities
# 4                    Other Biliary  2019  All Races and Ethnicities
# ..                             ...   ...                        ...
# 481            Male Genital System  2019                      White
# 482          Melanomas of the Skin  2019                      White
# 483  Anus Anal Canal and Anorectum  2019  All Races and Ethnicities
# 484                Chronic Myeloid  2019  All Races and Ethnicities
# 485               Endocrine System  2019  All Races and Ethnicities
#
#                  Sex   AgeGroup           RateType   DataType   Rate   Count  \
# ...

# %%
Dataset1.columns
# Out:
# Index(['CancerType', 'Year', 'Race', 'Sex', 'AgeGroup', 'RateType', 'DataType',
#        'Rate', 'Count', 'Population'],
#       dtype='object')

# %%
print(pd.unique(Dataset1['Race']))
# Out:
# ['All Races and Ethnicities' 'American Indian/Alaska Native'
#  'Asian/Pacific Islander' 'Black' 'Hispanic' 'White']

# %%
Dataset1 = Dataset1[['CancerType','Race','Rate','Count','Population']]

# %%
Dataset1
# Out:
#                         CancerType                       Race   Rate   Count  \
# 0      Other Female Genital Organs  All Races and Ethnicities    1.9    4199
# 1                      Nasopharynx  All Races and Ethnicities    0.5    1880
# 2                           Larynx  All Races and Ethnicities    2.9   12077
# 3             Non-Hodgkin Lymphoma  All Races and Ethnicities   18.1   71575
# 4                    Other Biliary  All Races and Ethnicities    1.6    6613
# ..                             ...                        ...    ...     ...
# 481            Male Genital System                      White  109.6  181845
# 482          Melanomas of the Skin                      White   25.8   81711
# 483  Anus Anal Canal and Anorectum  All Races and Ethnicities      2    8066
# 484                Chronic Myeloid  All Races and Ethnicities    1.9    6983
# 485               Endocrine System  All Races and Ethnicities   13.9   48152
#
#     Population
# 0    165096351
# ...

# %%
Dataset1.drop(Dataset1[Dataset1["CancerType"] == 'All Cancer Sites Combined'].index, inplace = True)
Dataset1.drop(Dataset1[Dataset1["CancerType"] == "All Sites (comparable to ICD-O-2)"].index, inplace = True)
Dataset1
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/3555358404.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.drop(Dataset1[Dataset1["CancerType"] == 'All Cancer Sites Combined'].index, inplace = True)
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/3555358404.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.drop(Dataset1[Dataset1["CancerType"] == "All Sites (comparable to ICD-O-2)"].index, inplace = True)
#                         CancerType                       Race   Rate   Count  \
# ...

# %%
Dataset1_index = Dataset1.set_index("Race")
Dataset1_index.head()
# Out:
#                                             CancerType  Rate  Count Population
# Race
# All Races and Ethnicities  Other Female Genital Organs   1.9   4199  165096351
# All Races and Ethnicities                  Nasopharynx   0.5   1880  325239182
# All Races and Ethnicities                       Larynx   2.9  12077  325239182
# All Races and Ethnicities         Non-Hodgkin Lymphoma  18.1  71575  325239182
# All Races and Ethnicities                Other Biliary   1.6   6613  325239182

# %%
Dataset1_index.reset_index()
# Out:
#                           Race                     CancerType   Rate   Count  \
# 0    All Races and Ethnicities    Other Female Genital Organs    1.9    4199
# 1    All Races and Ethnicities                    Nasopharynx    0.5    1880
# 2    All Races and Ethnicities                         Larynx    2.9   12077
# 3    All Races and Ethnicities           Non-Hodgkin Lymphoma   18.1   71575
# 4    All Races and Ethnicities                  Other Biliary    1.6    6613
# ..                         ...                            ...    ...     ...
# 469                      White            Male Genital System  109.6  181845
# 470                      White          Melanomas of the Skin   25.8   81711
# 471  All Races and Ethnicities  Anus Anal Canal and Anorectum      2    8066
# 472  All Races and Ethnicities                Chronic Myeloid    1.9    6983
# 473  All Races and Ethnicities               Endocrine System   13.9   48152
#
#     Population
# 0    165096351
# ...

# %%
for c in Dataset1_index.columns:
    miss = Dataset1_index[c].isnull().sum()
    if miss>0:
        print("{} has {} missing value(s)".format(c,miss))
    else:
        print("{} has No missing value(s)".format(c))
# Out:
# CancerType has No missing value(s)
# Rate has No missing value(s)
# Count has No missing value(s)
# Population has No missing value(s)

# %%
Dataset1_new = Dataset1_index.groupby('Race')
Dataset1_new

# %%
Dataset1.AllRaces = Dataset1_new.get_group('All Races and Ethnicities')
Dataset1.AllRaces
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/3309121735.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Dataset1.AllRaces = Dataset1_new.get_group('All Races and Ethnicities')
#                                                CancerType  Rate  Count  \
# Race
# All Races and Ethnicities     Other Female Genital Organs   1.9   4199
# All Races and Ethnicities                     Nasopharynx   0.5   1880
# All Races and Ethnicities                          Larynx   2.9  12077
# All Races and Ethnicities            Non-Hodgkin Lymphoma  18.1  71575
# All Races and Ethnicities                   Other Biliary   1.6   6613
# ...                                                   ...   ...    ...
# All Races and Ethnicities  Brain and Other Nervous System   6.1  22538
# All Races and Ethnicities                     Hypopharynx   0.5   2156
# ...

# %%
Dataset1.AllRaces.reset_index()
# Out:
#                          Race                      CancerType  Rate  Count  \
# 0   All Races and Ethnicities     Other Female Genital Organs   1.9   4199
# 1   All Races and Ethnicities                     Nasopharynx   0.5   1880
# 2   All Races and Ethnicities                          Larynx   2.9  12077
# 3   All Races and Ethnicities            Non-Hodgkin Lymphoma  18.1  71575
# 4   All Races and Ethnicities                   Other Biliary   1.6   6613
# ..                        ...                             ...   ...    ...
# 74  All Races and Ethnicities  Brain and Other Nervous System   6.1  22538
# 75  All Races and Ethnicities                     Hypopharynx   0.5   2156
# 76  All Races and Ethnicities   Anus Anal Canal and Anorectum     2   8066
# 77  All Races and Ethnicities                 Chronic Myeloid   1.9   6983
# 78  All Races and Ethnicities                Endocrine System  13.9  48152
#
#    Population
# 0   165096351
# 1   325239182
# 2   325239182
# ...

# %%
Dataset1.AllRaces['Rate'] = Dataset1.AllRaces['Rate'].astype(float)
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/2304184135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.AllRaces['Rate'] = Dataset1.AllRaces['Rate'].astype(float)

# %%
Dataset1.AllRaces_index = Dataset1.AllRaces.set_index("CancerType")
Dataset1.AllRaces_index
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/614007023.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Dataset1.AllRaces_index = Dataset1.AllRaces.set_index("CancerType")
#                                 Rate  Count Population
# CancerType
# Other Female Genital Organs      1.9   4199  165096351
# Nasopharynx                      0.5   1880  325239182
# Larynx                           2.9  12077  325239182
# Non-Hodgkin Lymphoma            18.1  71575  325239182
# Other Biliary                    1.6   6613  325239182
# ...                              ...    ...        ...
# Brain and Other Nervous System   6.1  22538  325239182
# Hypopharynx                      0.5   2156  325239182
# Anus Anal Canal and Anorectum    2.0   8066  325239182
# Chronic Myeloid                  1.9   6983  325239182
# ...

# %%
Dataset1.AllRaces_index['Rate'].nlargest(2)
# Out:
# CancerType
# Female Breast          129.7
# Male Genital System    118.3
# Name: Rate, dtype: float64

# %%
Dataset1.AllRaces_index['Rate'].nsmallest(2)
# Out:
# CancerType
# Pleura                           0.0
# Other Oral Cavity and Pharynx    0.1
# Name: Rate, dtype: float64

# %%
Dataset1.AllRaces.plot.bar(x ='CancerType', y ='Rate', rot=0, figsize = (120, 50))
# Out:
# <AxesSubplot:xlabel='CancerType'>

# %%
Dataset1.white = Dataset1_new.get_group('White')
Dataset1.white
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/4260500484.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Dataset1.white = Dataset1_new.get_group('White')
#                            CancerType   Rate   Count Population
# Race
# White  Brain and Other Nervous System    6.6   19500  252224952
# White               Lung and Bronchus   53.7  187091  252224952
# White                           Ovary    9.8   16104  127256808
# White          Male and Female Breast   68.6  216782  252224952
# White                   Miscellaneous   15.2   50555  252224952
# ...                               ...    ...     ...        ...
# White                 Chronic Myeloid    1.9    5796  252224952
# White                Endocrine System   14.3   39067  252224952
# White                       Lymphomas   21.3   67788  252224952
# ...

# %%
Dataset1.white.reset_index()
# Out:
#      Race                      CancerType   Rate   Count Population
# 0   White  Brain and Other Nervous System    6.6   19500  252224952
# 1   White               Lung and Bronchus   53.7  187091  252224952
# 2   White                           Ovary    9.8   16104  127256808
# 3   White          Male and Female Breast   68.6  216782  252224952
# 4   White                   Miscellaneous   15.2   50555  252224952
# ..    ...                             ...    ...     ...        ...
# 74  White                 Chronic Myeloid    1.9    5796  252224952
# 75  White                Endocrine System   14.3   39067  252224952
# 76  White                       Lymphomas   21.3   67788  252224952
# 77  White             Male Genital System  109.6  181845  124968144
# 78  White           Melanomas of the Skin   25.8   81711  252224952
#
# [79 rows x 5 columns]

# %%
Dataset1.white['Rate'].dtypes
# Out:
# dtype('O')

# %%
Dataset1.white['Rate'] = Dataset1.white['Rate'].astype(float)
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/3978581025.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.white['Rate'] = Dataset1.white['Rate'].astype(float)

# %%
Dataset1.white_index = Dataset1.white.set_index("CancerType")
Dataset1.white_index
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/332404399.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Dataset1.white_index = Dataset1.white.set_index("CancerType")
#                                  Rate   Count Population
# CancerType
# Brain and Other Nervous System    6.6   19500  252224952
# Lung and Bronchus                53.7  187091  252224952
# Ovary                             9.8   16104  127256808
# Male and Female Breast           68.6  216782  252224952
# Miscellaneous                    15.2   50555  252224952
# ...                               ...     ...        ...
# Chronic Myeloid                   1.9    5796  252224952
# Endocrine System                 14.3   39067  252224952
# Lymphomas                        21.3   67788  252224952
# Male Genital System             109.6  181845  124968144
# ...

# %%
Dataset1.white_index['Rate'].nlargest(2)
# Out:
# CancerType
# Female Breast          130.3
# Male Genital System    109.6
# Name: Rate, dtype: float64

# %%
Dataset1.white_index['Rate'].nsmallest(2)
# Out:
# CancerType
# Pleura                           0.0
# Other Oral Cavity and Pharynx    0.1
# Name: Rate, dtype: float64

# %%
Dataset1.white.plot.bar(x ='CancerType', y ='Rate', rot=0, figsize = (120, 50))
# Out:
# <AxesSubplot:xlabel='CancerType'>

# %%
Dataset1.Black = Dataset1_new.get_group('Black')
Dataset1.Black
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/1189066531.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Dataset1.Black = Dataset1_new.get_group('Black')
#                    CancerType  Rate  Count Population
# Race
# Black                  Cervix   8.2   1972   24137605
# Black        Bones and Joints   0.8    370   46436481
# Black        Colon and Rectum  39.8  17614   46436481
# Black  Colon excluding Rectum  29.4  12898   46436481
# Black             Nasopharynx   0.6    278   46436481
# ...                       ...   ...    ...        ...
# Black         Chronic Myeloid   1.6    700   46436481
# Black        Endocrine System   8.5   3832   46436481
# Black               Lymphomas  15.6   6975   46436481
# Black     Male Genital System   172  36044   22298876
# Black   Melanomas of the Skin   0.9    386   46436481
#
# ...

# %%
Dataset1.Black['Rate'] = Dataset1.Black['Rate'].replace(['Data Suppressed'], '0')
Dataset1.Black
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/3724262228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.Black['Rate'] = Dataset1.Black['Rate'].replace(['Data Suppressed'], '0')
#                    CancerType  Rate  Count Population
# Race
# Black                  Cervix   8.2   1972   24137605
# Black        Bones and Joints   0.8    370   46436481
# Black        Colon and Rectum  39.8  17614   46436481
# Black  Colon excluding Rectum  29.4  12898   46436481
# Black             Nasopharynx   0.6    278   46436481
# ...                       ...   ...    ...        ...
# Black         Chronic Myeloid   1.6    700   46436481
# Black        Endocrine System   8.5   3832   46436481
# ...

# %%
Dataset1.Black['Rate'] = Dataset1.Black['Rate'].astype(float)
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/3105607165.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.Black['Rate'] = Dataset1.Black['Rate'].astype(float)

# %%
Dataset1.Black['Rate'].mean()
# Out:
# 15.232911392405065

# %%
round(25.37283950617284,2)
# Out:
# 25.37

# %%
Dataset1.Black['Rate'] = Dataset1.Black['Rate'].replace(['0'], '25.37')
Dataset1.Black
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/3168902466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.Black['Rate'] = Dataset1.Black['Rate'].replace(['0'], '25.37')
#                    CancerType   Rate  Count Population
# Race
# Black                  Cervix    8.2   1972   24137605
# Black        Bones and Joints    0.8    370   46436481
# Black        Colon and Rectum   39.8  17614   46436481
# Black  Colon excluding Rectum   29.4  12898   46436481
# Black             Nasopharynx    0.6    278   46436481
# ...                       ...    ...    ...        ...
# Black         Chronic Myeloid    1.6    700   46436481
# Black        Endocrine System    8.5   3832   46436481
# ...

# %%
Dataset1.black_index = Dataset1.Black.set_index("CancerType")
Dataset1.black_index
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/3202040527.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Dataset1.black_index = Dataset1.Black.set_index("CancerType")
#                          Rate  Count Population
# CancerType
# Cervix                    8.2   1972   24137605
# Bones and Joints          0.8    370   46436481
# Colon and Rectum         39.8  17614   46436481
# Colon excluding Rectum   29.4  12898   46436481
# Nasopharynx               0.6    278   46436481
# ...                       ...    ...        ...
# Chronic Myeloid           1.6    700   46436481
# Endocrine System          8.5   3832   46436481
# Lymphomas                15.6   6975   46436481
# Male Genital System     172.0  36044   22298876
# Melanomas of the Skin     0.9    386   46436481
#
# [79 rows x 3 columns]

# %%
Dataset1.black_index['Rate'].nlargest(2)
# Out:
# CancerType
# Male Genital System    172.0
# Prostate               169.7
# Name: Rate, dtype: float64

# %%
Dataset1.black_index['Rate'].nsmallest(2)
# Out:
# CancerType
# Pleura                           0.0
# Other Oral Cavity and Pharynx    0.1
# Name: Rate, dtype: float64

# %%
Dataset1.Black.plot.bar(x ='CancerType', y ='Rate', rot=0, figsize = (120, 50));

# %%
Dataset1.Hispanic = Dataset1_new.get_group('Hispanic')
Dataset1.Hispanic
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/2236976057.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Dataset1.Hispanic = Dataset1_new.get_group('Hispanic')
#                       CancerType  Rate  Count Population
# Race
# Hispanic        Bones and Joints     1    541   59496798
# Hispanic                  Corpus  25.6   6396   29481430
# Hispanic        Colon and Rectum    32  14083   59496798
# Hispanic  Colon excluding Rectum    22   9470   59496798
# Hispanic             Nasopharynx   0.4    182   59496798
# ...                          ...   ...    ...        ...
# Hispanic         Chronic Myeloid   1.6    756   59496798
# Hispanic        Endocrine System  14.3   7537   59496798
# Hispanic               Lymphomas  19.2   8648   59496798
# Hispanic     Male Genital System  91.4  18308   30015368
# ...

# %%
Dataset1.Hispanic['Rate'] = Dataset1.Hispanic['Rate'].replace(['Data Suppressed'], '0')
Dataset1.Hispanic
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/880992849.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.Hispanic['Rate'] = Dataset1.Hispanic['Rate'].replace(['Data Suppressed'], '0')
#                       CancerType  Rate  Count Population
# Race
# Hispanic        Bones and Joints     1    541   59496798
# Hispanic                  Corpus  25.6   6396   29481430
# Hispanic        Colon and Rectum    32  14083   59496798
# Hispanic  Colon excluding Rectum    22   9470   59496798
# Hispanic             Nasopharynx   0.4    182   59496798
# ...                          ...   ...    ...        ...
# Hispanic         Chronic Myeloid   1.6    756   59496798
# ...

# %%
Dataset1.Hispanic['Rate'] = Dataset1.Hispanic['Rate'].astype(float)
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/2313428655.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.Hispanic['Rate'] = Dataset1.Hispanic['Rate'].astype(float)

# %%
Dataset1.Hispanic['Rate'].mean()
# Out:
# 11.794936708860757

# %%
round(19.944444444444446,2)
# Out:
# 19.94

# %%
Dataset1.Hispanic['Rate'] = Dataset1.Hispanic['Rate'].replace(['0'], '19.94')
Dataset1.Hispanic
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/4753108.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.Hispanic['Rate'] = Dataset1.Hispanic['Rate'].replace(['0'], '19.94')
#                       CancerType  Rate  Count Population
# Race
# Hispanic        Bones and Joints   1.0    541   59496798
# Hispanic                  Corpus  25.6   6396   29481430
# Hispanic        Colon and Rectum  32.0  14083   59496798
# Hispanic  Colon excluding Rectum  22.0   9470   59496798
# Hispanic             Nasopharynx   0.4    182   59496798
# ...                          ...   ...    ...        ...
# Hispanic         Chronic Myeloid   1.6    756   59496798
# Hispanic        Endocrine System  14.3   7537   59496798
# ...

# %%
Dataset1.Hispanic_index = Dataset1.Hispanic.set_index("CancerType")
Dataset1.Hispanic_index
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/3452497734.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Dataset1.Hispanic_index = Dataset1.Hispanic.set_index("CancerType")
#                         Rate  Count Population
# CancerType
# Bones and Joints         1.0    541   59496798
# Corpus                  25.6   6396   29481430
# Colon and Rectum        32.0  14083   59496798
# Colon excluding Rectum  22.0   9470   59496798
# Nasopharynx              0.4    182   59496798
# ...                      ...    ...        ...
# Chronic Myeloid          1.6    756   59496798
# Endocrine System        14.3   7537   59496798
# Lymphomas               19.2   8648   59496798
# Male Genital System     91.4  18308   30015368
# Melanomas of the Skin    4.5   2035   59496798
#
# [79 rows x 3 columns]

# %%
Dataset1.Hispanic_index['Rate'].nlargest(2)
# Out:
# CancerType
# Female Breast          101.9
# Male Genital System     91.4
# Name: Rate, dtype: float64

# %%
Dataset1.Hispanic_index['Rate'].nsmallest(2)
# Out:
# CancerType
# Pleura                           0.0
# Other Oral Cavity and Pharynx    0.1
# Name: Rate, dtype: float64

# %%
Dataset1.Hispanic.plot.bar(x ='CancerType', y ='Rate', rot=0, figsize = (120, 50));

# %%
Dataset1.Asian_Pacific_Islander = Dataset1_new.get_group('Asian/Pacific Islander')
Dataset1.Asian_Pacific_Islander
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/2873690858.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Dataset1.Asian_Pacific_Islander = Dataset1_new.get_group('Asian/Pacific Islander')
#                                               CancerType  Rate Count  \
# Race
# Asian/Pacific Islander             Corpus and Uterus NOS  21.5  2668
# Asian/Pacific Islander                       Gallbladder   1.3   272
# Asian/Pacific Islander  Liver and Intrahepatic Bile Duct  11.4  2484
# Asian/Pacific Islander           Oral Cavity and Pharynx   7.9  1758
# Asian/Pacific Islander           Kidney and Renal Pelvis   7.9  1740
# ...                                                  ...   ...   ...
# Asian/Pacific Islander                         Esophagus     2   441
# Asian/Pacific Islander                   Other Leukemias   0.8   166
# ...

# %%
Dataset1.Asian_Pacific_Islander['Rate'] = Dataset1.Asian_Pacific_Islander['Rate'].replace(['Data Suppressed'], '0')
Dataset1.Asian_Pacific_Islander
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/1205772607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.Asian_Pacific_Islander['Rate'] = Dataset1.Asian_Pacific_Islander['Rate'].replace(['Data Suppressed'], '0')
#                                               CancerType  Rate Count  \
# Race
# Asian/Pacific Islander             Corpus and Uterus NOS  21.5  2668
# Asian/Pacific Islander                       Gallbladder   1.3   272
# Asian/Pacific Islander  Liver and Intrahepatic Bile Duct  11.4  2484
# Asian/Pacific Islander           Oral Cavity and Pharynx   7.9  1758
# Asian/Pacific Islander           Kidney and Renal Pelvis   7.9  1740
# ...

# %%
Dataset1.Asian_Pacific_Islander['Rate'] = Dataset1.Asian_Pacific_Islander['Rate'].astype(float)
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/1981891047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.Asian_Pacific_Islander['Rate'] = Dataset1.Asian_Pacific_Islander['Rate'].astype(float)

# %%
Dataset1.Asian_Pacific_Islander['Rate'].mean()
# Out:
# 9.794936708860757

# %%
round(16.588888888888885,2)
# Out:
# 16.59

# %%
Dataset1.Asian_Pacific_Islander['Rate'] = Dataset1.Asian_Pacific_Islander['Rate'].replace(['0'], '16.59')
Dataset1.Asian_Pacific_Islander
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/3108527211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.Asian_Pacific_Islander['Rate'] = Dataset1.Asian_Pacific_Islander['Rate'].replace(['0'], '16.59')
#                                               CancerType  Rate Count  \
# Race
# Asian/Pacific Islander             Corpus and Uterus NOS  21.5  2668
# Asian/Pacific Islander                       Gallbladder   1.3   272
# Asian/Pacific Islander  Liver and Intrahepatic Bile Duct  11.4  2484
# Asian/Pacific Islander           Oral Cavity and Pharynx   7.9  1758
# Asian/Pacific Islander           Kidney and Renal Pelvis   7.9  1740
# ...                                                  ...   ...   ...
# ...

# %%
Dataset1.Asian_Pacific_Islander_index = Dataset1.Asian_Pacific_Islander.set_index("CancerType")
Dataset1.Asian_Pacific_Islander_index
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/3162641269.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Dataset1.Asian_Pacific_Islander_index = Dataset1.Asian_Pacific_Islander.set_index("CancerType")
#                                   Rate Count Population
# CancerType
# Corpus and Uterus NOS             21.5  2668   11316721
# Gallbladder                        1.3   272   21796562
# Liver and Intrahepatic Bile Duct  11.4  2484   21796562
# Oral Cavity and Pharynx            7.9  1758   21796562
# Kidney and Renal Pelvis            7.9  1740   21796562
# ...                                ...   ...        ...
# Esophagus                          2.0   441   21796562
# Other Leukemias                    0.8   166   21796562
# Prostate                          57.3  5623   10479841
# Rectum and Rectosigmoid Junction   9.9  2198   21796562
# ...

# %%
Dataset1.Asian_Pacific_Islander_index['Rate'].nlargest(2)
# Out:
# CancerType
# Female Breast       103.1
# Digestive System     65.9
# Name: Rate, dtype: float64

# %%
Dataset1.Asian_Pacific_Islander_index['Rate'].nsmallest(3)
# Out:
# CancerType
# Pleura                                              0.0
# Other Oral Cavity and Pharynx                       0.0
# Trachea Mediastinum and Other Respiratory Organs    0.1
# Name: Rate, dtype: float64

# %%
Dataset1.Asian_Pacific_Islander.plot.bar(x ='CancerType', y ='Rate', rot=0, figsize = (120, 50));

# %%
Dataset1.American_Indian_Alaska_Native = Dataset1_new.get_group('American Indian/Alaska Native')
Dataset1.American_Indian_Alaska_Native
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/731697226.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Dataset1.American_Indian_Alaska_Native = Dataset1_new.get_group('American Indian/Alaska Native')
#                                                      CancerType  Rate Count  \
# Race
# American Indian/Alaska Native           Kidney and Renal Pelvis  16.4   689
# American Indian/Alaska Native                  Bones and Joints   0.5    23
# American Indian/Alaska Native             Corpus and Uterus NOS  17.8   395
# American Indian/Alaska Native                       Gallbladder   1.1    39
# American Indian/Alaska Native                  Colon and Rectum    27  1071
# ...                                                         ...   ...   ...
# American Indian/Alaska Native                           Stomach   5.1   198
# ...

# %%
Dataset1.American_Indian_Alaska_Native['Rate'] = Dataset1.American_Indian_Alaska_Native['Rate'].replace(['Data Suppressed'], '0')
Dataset1.American_Indian_Alaska_Native
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/1504969886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.American_Indian_Alaska_Native['Rate'] = Dataset1.American_Indian_Alaska_Native['Rate'].replace(['Data Suppressed'], '0')
#                                                      CancerType  Rate Count  \
# Race
# American Indian/Alaska Native           Kidney and Renal Pelvis  16.4   689
# American Indian/Alaska Native                  Bones and Joints   0.5    23
# American Indian/Alaska Native             Corpus and Uterus NOS  17.8   395
# American Indian/Alaska Native                       Gallbladder   1.1    39
# American Indian/Alaska Native                  Colon and Rectum    27  1071
# ...

# %%
Dataset1.American_Indian_Alaska_Native['Rate'] = Dataset1.American_Indian_Alaska_Native['Rate'].astype(float)
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/2859950053.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.American_Indian_Alaska_Native['Rate'] = Dataset1.American_Indian_Alaska_Native['Rate'].astype(float)

# %%
Dataset1.American_Indian_Alaska_Native['Rate'].mean()
# Out:
# 8.812658227848098

# %%
round(15.182716049382716,2)
# Out:
# 15.18

# %%
Dataset1.American_Indian_Alaska_Native['Rate'] = Dataset1.American_Indian_Alaska_Native['Rate'].replace(['0'], '15.18')
Dataset1.American_Indian_Alaska_Native
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/2813962894.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dataset1.American_Indian_Alaska_Native['Rate'] = Dataset1.American_Indian_Alaska_Native['Rate'].replace(['0'], '15.18')
#                                                      CancerType  Rate Count  \
# Race
# American Indian/Alaska Native           Kidney and Renal Pelvis  16.4   689
# American Indian/Alaska Native                  Bones and Joints   0.5    23
# American Indian/Alaska Native             Corpus and Uterus NOS  17.8   395
# American Indian/Alaska Native                       Gallbladder   1.1    39
# American Indian/Alaska Native                  Colon and Rectum  27.0  1071
# ...

# %%
Dataset1.American_Indian_Alaska_Native_index = Dataset1.American_Indian_Alaska_Native.set_index("CancerType")
Dataset1.American_Indian_Alaska_Native_index
# Out:
# /var/folders/_7/pbht2t6x6rz03vl0j09blw7c0000gn/T/ipykernel_88698/1757205266.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   Dataset1.American_Indian_Alaska_Native_index = Dataset1.American_Indian_Alaska_Native.set_index("CancerType")
#                                   Rate Count Population
# CancerType
# Kidney and Renal Pelvis           16.4   689    4781187
# Bones and Joints                   0.5    23    4781187
# Corpus and Uterus NOS             17.8   395    2385217
# Gallbladder                        1.1    39    4781187
# Colon and Rectum                  27.0  1071    4781187
# ...                                ...   ...        ...
# Stomach                            5.1   198    4781187
# Esophagus                          3.4   133    4781187
# Other Leukemias                    1.0    38    4781187
# ...

# %%
Dataset1.American_Indian_Alaska_Native_index['Rate'].nlargest(2)
# Out:
# CancerType
# Female Breast       73.1
# Digestive System    60.6
# Name: Rate, dtype: float64

# %%
Dataset1.American_Indian_Alaska_Native_index['Rate'].nsmallest(16)
# Out:
# CancerType
# Lip                                                 0.0
# Penis                                               0.0
# Peritoneum Omentum and Mesentery                    0.0
# Other Oral Cavity and Pharynx                       0.0
# Vagina                                              0.0
# Floor of Mouth                                      0.0
# Other Urinary Organs                                0.0
# Trachea Mediastinum and Other Respiratory Organs    0.0
# Other Male Genital Organs                           0.0
# Retroperitoneum                                     0.0
# Cranial Nerves and Other Nervous System             0.0
# Kaposi Sarcoma                                      0.0
# Other Digestive Organs                              0.0
# Pleura                                              0.0
# Ureter                                              0.0
# Nasopharynx                                         0.4
# Name: Rate, dtype: float64

# %%
Dataset1.American_Indian_Alaska_Native.plot.bar(x ='CancerType', y ='Rate', rot=0,figsize = (120, 50));
